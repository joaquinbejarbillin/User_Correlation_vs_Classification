# %%
# %load_ext autoreload

# %autoreload 2

# %matplotlib inline

# %%
import pandas as pd

from library import *

# %%
host = '10.0.5.225'
db = 'billin'
user = 'postgres'
password = 'ppoSgre123'

# %%
db = DB()

# %%
f_business_info = db.gettable('f_business_info')

# %%
f_business_info.head()
# Out:
#    id_business fecha_registro                                      fiscalname  \
# 0        90752     07/08/2018                     Ben amer el khayat mohammed
# 1        91400     09/08/2018  BILLINDEMO04a27bc7-42d1-4d77-a8c0-4deef5000b46
# 2       106108     28/08/2018                             DEBORA LORENA APPES
# 3       107269     08/09/2018                       ENRIQUE CARRILLO MARTINEZ
# 4       102673     30/07/2018                                        REINALDO
#
#    telephone business_type                is_premium  \
# 0  66991025D     freelance  ACTIVA MENSUAL CON CUPON
# 1       None       company  ACTIVA MENSUAL CON CUPON
# 2       None     freelance                       N/A
# 3  675657211     freelance                       N/A
# 4  722704777     freelance                       N/A
#
#                     usuarios_email                    ga_source ga_medium  \
# 0             beni9516@hotmail.com                     (direct)    (none)
# 1  mauricio.torres@smhproducts.com  empresas3.gruposantander.es  referral
# 2             debappes@hotmail.com                      crmt v3     email
# 3            encama_59@hotmail.com                       google       cpc
# 4          reinaldoveitia@yahoo.es                       google       cpc
#
#                        ga_campaign       ...        num_presupuestos_45  \
# 0                        (not set)       ...                          0
# 1                        (not set)       ...                          0
# 2                  invitar usuario       ...                          0
# 3  QRZ_BILLIN_20171220_MIME__1_E&P       ...                          0
# 4  QRZ_BILLIN_20171220_MIME__1_E&P       ...                          0
#
#   num_negocios_viralizados ultima_conexion num_facturas_simples  \
# 0                        0      20180819.0                    0
# 1                        0      20180809.0                    0
# 2                        0      20180828.0                    0
# 3                        0      20180908.0                    0
# 4                        0      20180730.0                    0
#
#   num_facturas_simples_45  direccion_country  ip_country  \
# 0                       0             Espana      Espana
# 1                       0               None      Espana
# 2                       0             Espana      Espana
# 3                       0             Espana      Espana
# 4                       0               None      Espana
#
#                        uuid_business_id  \
# 0  feb8fa10-08bc-47a9-8c55-84624bccc469
# 1  678039ed-65d7-4cdf-9d59-c36147dafee3
# 2  cce0d3b4-8ba0-4a61-9242-617655cc60fc
# 3  e98a5706-3cf3-43d4-b0a8-ffb0263fc607
# 4  197d9c7f-7c75-4ee9-b75e-bc1921444c74
#
#                                           nif_cif      signup_from
# 0                                       78991025D    direct_signup
# 1  BILLINDEMO6911138B-BF29-40BA-8E47-83C3CE6C0FD9    direct_signup
# 2                                       X6306795B  contact_request
# 3                                       27261556R           singup
# 4                                       54703747H           singup
#
# [5 rows x 44 columns]

# %%
f_business_info.drop(columns=['id_business', 'fiscalname', 'telephone', 'usuarios_email', 'nif_cif', 'signup_from','direccion_country','ip_country'], inplace=True)

# %%
results = f_business_info.copy()

# %%
results.set_index('uuid_business_id', inplace=True)

# %%
results.columns
# Out:
# Index(['fecha_registro', 'business_type', 'is_premium', 'ga_source',
#        'ga_medium', 'ga_campaign', 'ga_adcontent', 'ga_keyword',
#        'affiliated_id', 'billin_campaign', 'billin_campaign_data',
#        'num_usuarios', 'num_conexiones', 'num_contactos',
#        'num_contactos_billin', 'num_contactos_correo', 'num_contactos_privado',
#        'num_facturas', 'num_facturas_emitidas', 'num_facturas_enviadas',
#        'num_facturas_recibidas', 'importe_total_facturas',
#        'importe_medio_facturas', 'num_presupuestos', 'num_conexiones_45',
#        'num_contactos_45', 'num_facturas_45', 'num_facturas_emitidas_45',
#        'num_facturas_enviadas_45', 'num_facturas_recibidas_45',
#        'num_presupuestos_45', 'num_negocios_viralizados', 'ultima_conexion',
#        'num_facturas_simples', 'num_facturas_simples_45'],
#       dtype='object')

# %%
results = pd.concat([results, days_ago(results.fecha_registro), days_ago(pd.to_datetime(results.ultima_conexion,yearfirst=True, format='%Y%m%d.0'))], axis=1)

# %%
results.drop(columns=['fecha_registro', 'ultima_conexion'], inplace=True)

# %%
results['never_used'] = results.fecha_registro_days_ago == results.ultima_conexion_days_ago

# %%
results.head()
# Out:
#                                      business_type                is_premium  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469     freelance  ACTIVA MENSUAL CON CUPON
# 678039ed-65d7-4cdf-9d59-c36147dafee3       company  ACTIVA MENSUAL CON CUPON
# cce0d3b4-8ba0-4a61-9242-617655cc60fc     freelance                       N/A
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607     freelance                       N/A
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74     freelance                       N/A
#
#                                                         ga_source ga_medium  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                     (direct)    (none)
# 678039ed-65d7-4cdf-9d59-c36147dafee3  empresas3.gruposantander.es  referral
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                      crmt v3     email
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                       google       cpc
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                       google       cpc
#
#                                                           ga_campaign  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                        (not set)
# 678039ed-65d7-4cdf-9d59-c36147dafee3                        (not set)
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                  invitar usuario
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607  QRZ_BILLIN_20171220_MIME__1_E&P
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74  QRZ_BILLIN_20171220_MIME__1_E&P
#
#                                      ga_adcontent ga_keyword affiliated_id  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469         None       None          None
# 678039ed-65d7-4cdf-9d59-c36147dafee3         None       None          None
# cce0d3b4-8ba0-4a61-9242-617655cc60fc         None       None          None
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607         None       None          None
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74         None       None          None
#
#                                      billin_campaign billin_campaign_data  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469     Popular2018                 None
# 678039ed-65d7-4cdf-9d59-c36147dafee3   Santander2018                 None
# cce0d3b4-8ba0-4a61-9242-617655cc60fc            None                 None
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607            None                 None
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74            None                 None
#
#                                          ...      num_facturas_emitidas_45  \
# uuid_business_id                         ...
# feb8fa10-08bc-47a9-8c55-84624bccc469     ...                             0
# 678039ed-65d7-4cdf-9d59-c36147dafee3     ...                             0
# cce0d3b4-8ba0-4a61-9242-617655cc60fc     ...                             0
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607     ...                             0
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74     ...                             0
#
#                                       num_facturas_enviadas_45  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                         0
# 678039ed-65d7-4cdf-9d59-c36147dafee3                         0
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                         0
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                         0
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                         0
#
#                                       num_facturas_recibidas_45  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                          0
# 678039ed-65d7-4cdf-9d59-c36147dafee3                          0
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                          1
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                          0
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                          0
#
#                                       num_presupuestos_45  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                    0
# 678039ed-65d7-4cdf-9d59-c36147dafee3                    0
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                    0
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                    0
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                    0
#
#                                       num_negocios_viralizados  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                         0
# 678039ed-65d7-4cdf-9d59-c36147dafee3                         0
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                         0
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                         0
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                         0
#
#                                       num_facturas_simples  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                     0
# 678039ed-65d7-4cdf-9d59-c36147dafee3                     0
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                     0
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                     0
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                     0
#
#                                       num_facturas_simples_45  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                        0
# 678039ed-65d7-4cdf-9d59-c36147dafee3                        0
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                        0
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                        0
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                        0
#
#                                       fecha_registro_days_ago  \
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                       35
# 678039ed-65d7-4cdf-9d59-c36147dafee3                       33
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                       14
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                        3
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                       43
#
#                                       ultima_conexion_days_ago  never_used
# uuid_business_id
# feb8fa10-08bc-47a9-8c55-84624bccc469                        23       False
# 678039ed-65d7-4cdf-9d59-c36147dafee3                        33        True
# cce0d3b4-8ba0-4a61-9242-617655cc60fc                        14        True
# e98a5706-3cf3-43d4-b0a8-ffb0263fc607                         3        True
# 197d9c7f-7c75-4ee9-b75e-bc1921444c74                        43        True
#
# [5 rows x 36 columns]

# %%
results.columns
# Out:
# Index(['business_type', 'is_premium', 'ga_source', 'ga_medium', 'ga_campaign',
#        'ga_adcontent', 'ga_keyword', 'affiliated_id', 'billin_campaign',
#        'billin_campaign_data', 'num_usuarios', 'num_conexiones',
#        'num_contactos', 'num_contactos_billin', 'num_contactos_correo',
#        'num_contactos_privado', 'num_facturas', 'num_facturas_emitidas',
#        'num_facturas_enviadas', 'num_facturas_recibidas',
#        'importe_total_facturas', 'importe_medio_facturas', 'num_presupuestos',
#        'num_conexiones_45', 'num_contactos_45', 'num_facturas_45',
#        'num_facturas_emitidas_45', 'num_facturas_enviadas_45',
#        'num_facturas_recibidas_45', 'num_presupuestos_45',
#        'num_negocios_viralizados', 'num_facturas_simples',
#        'num_facturas_simples_45', 'fecha_registro_days_ago',
#        'ultima_conexion_days_ago', 'never_used'],
#       dtype='object')
