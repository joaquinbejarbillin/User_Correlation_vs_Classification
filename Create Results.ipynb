# %%
# %load_ext autoreload

# %autoreload 2

# %matplotlib inline

# %%
import pandas as pd

from library import *

# %%
host = '10.0.5.225'
db = 'billin'
user = 'postgres'
password = 'ppoSgre123'

# %%
db = DB()

# %%
f_business_info = db.gettable('f_business_info')

# %%
f_business_info.head()
# Out:
#    id_business fecha_registro             fiscalname  telephone business_type  \
# 0        78023     21/05/2017    ANTONIO LOPEZ GOMEZ  673319021     freelance
# 1        89748     10/04/2018  ANGELA MARIA MAS GARI  679374464     freelance
# 2        89893     23/02/2018     Mario Seoane Lopez  635753709     freelance
# 3        85716     05/12/2017             particular  971371464     freelance
# 4        97375     21/04/2018               ANDRES S  695673310     freelance
#
#   is_premium                          usuarios_email  ga_source  ga_medium  \
# 0        N/A                     alopez@viventie.com  (not set)  (not set)
# 1        N/A  alegnamas@hotmail.com / pep@ceinco.net     google        cpc
# 2        N/A                mario.seoane@hotmail.com  (not set)  (not set)
# 3        N/A            conchitacampspons@guimel.com     google        cpc
# 4        N/A                  vapepiper.es@gmail.com   (direct)     (none)
#
#         ga_campaign     ...      num_presupuestos_45 num_negocios_viralizados  \
# 0              None     ...                        0                        0
# 1  campaña de marca     ...                        0                        0
# 2              None     ...                        0                        0
# 3   Campaña Tráfico     ...                        0                        0
# 4         (not set)     ...                        0                        0
#
#   ultima_conexion num_facturas_simples num_facturas_simples_45  \
# 0      20170521.0                    0                       0
# 1      20180829.0                    0                       0
# 2      20180223.0                    0                       0
# 3      20171205.0                    0                       0
# 4      20180424.0                    0                       0
#
#    direccion_country  ip_country                      uuid_business_id  \
# 0             Espana        None  3178fa0c-fe75-4382-ace5-31a3240a44b4
# 1             Espana      Espana  fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8
# 2               None        None  8f9ed433-b892-4c0d-97c3-1961ee45ff8d
# 3               None        None  2345f583-e366-4bb5-a27d-64fb4ea3f178
# 4               None        None  ba11466a-9866-435f-93a3-9eedcc4dae8f
#
#      nif_cif  signup_from
# 0  75438477H       singup
# 1  41524884V       singup
# 2  78921344H       singup
# 3  41489151A       singup
# 4  55111405R       singup
#
# [5 rows x 44 columns]

# %%
f_business_info.drop(columns=['id_business', 'fiscalname', 'telephone', 'usuarios_email', 'nif_cif', 'signup_from','direccion_country','ip_country'], inplace=True)

# %%
results = f_business_info.copy()

# %%
results.set_index('uuid_business_id', inplace=True)

# %%
results.columns
# Out:
# Index(['business_type', 'is_premium', 'ga_source', 'ga_medium', 'ga_campaign',
#        'ga_adcontent', 'ga_keyword', 'affiliated_id', 'billin_campaign',
#        'billin_campaign_data', 'num_usuarios', 'num_conexiones',
#        'num_contactos', 'num_contactos_billin', 'num_contactos_correo',
#        'num_contactos_privado', 'num_facturas', 'num_facturas_emitidas',
#        'num_facturas_enviadas', 'num_facturas_recibidas',
#        'importe_total_facturas', 'importe_medio_facturas', 'num_presupuestos',
#        'num_conexiones_45', 'num_contactos_45', 'num_facturas_45',
#        'num_facturas_emitidas_45', 'num_facturas_enviadas_45',
#        'num_facturas_recibidas_45', 'num_presupuestos_45',
#        'num_negocios_viralizados', 'num_facturas_simples',
#        'num_facturas_simples_45', 'fecha_registro_days_ago',
#        'ultima_conexion_days_ago', 'never_used'],
#       dtype='object')

# %%
results = pd.concat([results, days_ago(results.fecha_registro), days_ago(pd.to_datetime(results.ultima_conexion,yearfirst=True, format='%Y%m%d.0'))], axis=1)

# %%
results.drop(columns=['fecha_registro', 'ultima_conexion'], inplace=True)

# %%
results['never_used'] = results.fecha_registro_days_ago == results.ultima_conexion_days_ago

# %%
results.head()
# Out:
#                                      business_type is_premium  ga_source  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4     freelance        N/A  (not set)
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8     freelance        N/A     google
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d     freelance        N/A  (not set)
# 2345f583-e366-4bb5-a27d-64fb4ea3f178     freelance        N/A     google
# ba11466a-9866-435f-93a3-9eedcc4dae8f     freelance        N/A   (direct)
#
#                                       ga_medium       ga_campaign  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4  (not set)              None
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8        cpc  campaña de marca
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d  (not set)              None
# 2345f583-e366-4bb5-a27d-64fb4ea3f178        cpc   Campaña Tráfico
# ba11466a-9866-435f-93a3-9eedcc4dae8f     (none)         (not set)
#
#                                      ga_adcontent ga_keyword affiliated_id  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4         None       None          None
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8         None       None          None
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d         None       None          None
# 2345f583-e366-4bb5-a27d-64fb4ea3f178         None       None          None
# ba11466a-9866-435f-93a3-9eedcc4dae8f         None       None          None
#
#                                      billin_campaign billin_campaign_data  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4            None                 None
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8            None                 None
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d            None                 None
# 2345f583-e366-4bb5-a27d-64fb4ea3f178            None                 None
# ba11466a-9866-435f-93a3-9eedcc4dae8f            None                 None
#
#                                          ...      num_facturas_emitidas_45  \
# uuid_business_id                         ...
# 3178fa0c-fe75-4382-ace5-31a3240a44b4     ...                             0
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8     ...                            29
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d     ...                             0
# 2345f583-e366-4bb5-a27d-64fb4ea3f178     ...                             0
# ba11466a-9866-435f-93a3-9eedcc4dae8f     ...                             0
#
#                                       num_facturas_enviadas_45  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                         0
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                         0
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                         0
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                         0
# ba11466a-9866-435f-93a3-9eedcc4dae8f                         0
#
#                                       num_facturas_recibidas_45  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                          0
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                          0
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                          0
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                          0
# ba11466a-9866-435f-93a3-9eedcc4dae8f                          0
#
#                                       num_presupuestos_45  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                    0
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                    0
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                    0
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                    0
# ba11466a-9866-435f-93a3-9eedcc4dae8f                    0
#
#                                       num_negocios_viralizados  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                         0
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                         0
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                         0
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                         0
# ba11466a-9866-435f-93a3-9eedcc4dae8f                         0
#
#                                       num_facturas_simples  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                     0
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                     0
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                     0
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                     0
# ba11466a-9866-435f-93a3-9eedcc4dae8f                     0
#
#                                       num_facturas_simples_45  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                        0
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                        0
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                        0
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                        0
# ba11466a-9866-435f-93a3-9eedcc4dae8f                        0
#
#                                       fecha_registro_days_ago  \
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                      470
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                      146
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                      192
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                      272
# ba11466a-9866-435f-93a3-9eedcc4dae8f                      135
#
#                                       ultima_conexion_days_ago  never_used
# uuid_business_id
# 3178fa0c-fe75-4382-ace5-31a3240a44b4                       470        True
# fc278a1c-f2f0-4cdc-b5bb-05471bbb98c8                         5       False
# 8f9ed433-b892-4c0d-97c3-1961ee45ff8d                       192        True
# 2345f583-e366-4bb5-a27d-64fb4ea3f178                       272        True
# ba11466a-9866-435f-93a3-9eedcc4dae8f                       132       False
#
# [5 rows x 36 columns]
