# %%
# %load_ext autoreload

# %autoreload 2

# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from library import *

# %%
df = get_invoices('nodejs','TresTRISTESTIGRESComianTrigoEnUnTrigal', 'production-shard-00-00-qlmse.mongodb.net', 'billin_prod')

# %%
lm = last_months(df, months=6)

# %%
lm
# Out:
#                                       -7  -6  -5  -4  -3  -2  -1       mean
# 0436222c-c5b7-4a90-a76d-bff8b9db2938   1   0   0   0   0   0   0   0.142857
# 277fde35-e825-4bc7-b100-3ec3abeebab1   1   0   0   0   0   0   0   0.142857
# 2d8ab5f0-65d4-4c54-90c4-a0f6f8c076c8   1   0   0   0   0   0   0   0.142857
# 2f54364c-eb40-4552-a8ba-153b68d8df36   0   0  20   0   0  21   0   5.857143
# 3cc85bf2-c99f-44f4-a004-3d19e792f2fc   4   5   4   5   6   0   2   3.714286
# 456bea26-7f79-4f1a-8249-cf8e24668153   1   0   0   0   0   0   0   0.142857
# 585a1368-7896-4e64-a103-62ae8f3a00f3   1   0   0   0   0   0   0   0.142857
# 5ec74fce-345b-44a4-8b0c-8193f01b154d   1   0   0   0   0   0   0   0.142857
# 6d30d9c1-45e8-4c4d-a7cc-1a6d09c217f1   1   0   0   0   0   0   0   0.142857
# a3979bfb-df84-47b2-a896-c280e3db1084   2   0   0   0   0   0   0   0.285714
# a59aed50-fbbd-45de-a28a-9265785b71af   1   0   0   0   0   0   0   0.142857
# d35a5e6e-4435-4a33-9bcd-977e25f09597   1   0   0   0   0   0   0   0.142857
# d5c3d170-fc84-46bd-90f7-2a961e99fdcb   0  14  14  12  29  13  12  13.428571
# e5966c7d-44fe-4347-a200-6d4a5c999bf5   1   0   0   0   0   0   0   0.142857
# f7df18a2-9b46-4d0a-9164-55084b2c83a6   0   7   0   4   3   0   1   2.142857
