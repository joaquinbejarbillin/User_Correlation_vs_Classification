# %%
# %load_ext autoreload

# %autoreload 2

# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from library import *

# %%
df = get_invoices('nodejs','TresTRISTESTIGRESComianTrigoEnUnTrigal', 'production-shard-00-00-qlmse.mongodb.net', 'billin_prod')

# %%
lm = last_months(df, months=6)

# %%
lm[lm['mean'] >10].shape
# Out:
# (325, 7)

# %%
lm
# Out:
#                                       -6  -5  -4  -3  -2  -1       mean
# 00cd6a6e-ffa6-404d-a6d2-f2c6cb1d4f1e   0   1  15  21  28  22  14.500000
# 0436222c-c5b7-4a90-a76d-bff8b9db2938   0   0   0   0   0   0   0.000000
# 09b64cf5-23ea-42db-8065-57b9e6de76db  35  14  32  19  12   8  20.000000
# 0c532b18-a1f7-4fc1-9294-3f8f5e956b4f   0   0   0   0   0   0   0.000000
# 277fde35-e825-4bc7-b100-3ec3abeebab1   0   0   0   0   0   0   0.000000
# 2d8ab5f0-65d4-4c54-90c4-a0f6f8c076c8   0   0   0   0   0   0   0.000000
# 2f54364c-eb40-4552-a8ba-153b68d8df36   0  20   0   0  21   0   6.833333
# 3cc85bf2-c99f-44f4-a004-3d19e792f2fc   5   4   5   6   0   2   3.666667
# 443e8b5f-14a2-4467-8d08-47ad38160bd3   0   0   0   0   0   0   0.000000
# 456bea26-7f79-4f1a-8249-cf8e24668153   0   0   0   0   0   0   0.000000
# 5027b6e6-02c7-4cdd-9e01-f4af05fb3441   0   0   0   0   0   0   0.000000
# 585a1368-7896-4e64-a103-62ae8f3a00f3   0   0   0   0   0   0   0.000000
# ...
